# %%
from prigen import PrimersGenerator
from prigen.utils import filter_primers_by_blast

# %% [markdown]
# ### Generate primers without temperature restrictions

# %%
generator = PrimersGenerator(length=20, gc_percentage=0.6)
primers = generator.generate_primers()
primers
# Out:
# {'TCTTTTCGCTCCCCCATCCC': 55.97,
#  'CGACCGTGTTGCTGATGGGT': 57.28,
#  'CTTCTTGATCGCGGACCCAG': 55.1,
#  'CCGCCCTTATCGGAGGGTTA': 55.22,
#  'GGGTTTCCGGCAAAGTGCAG': 56.67,
#  'GTCCCGGTACGAGGCAACTT': 56.35,
#  'GACGTCTGAGTGAGTTGCCG': 55.38,
#  'TCAACGCGGGTCGAGAAGAC': 56.77,
#  'GGGAGGGGGGAGTTATGAAG': 52.91,
#  'CGGGCTTCTCGCTCTTCCTT': 56.42,
#  'CAAGACCGGGCAGTTAACCC': 55.16,
#  'GGCGCGAAGAGACAGACGTA': 56.58,
#  'TACTCCCTTGCTCTGCGCTG': 56.43,
#  'ACCCACCTTCCTCTTTCCCC': 55.09,
#  'CTTTACCCATCCTCCTCCCC': 52.91,
#  'AGAGAGGGGAGAAGGAGGAG': 53.04,
#  'ACTGAGGGGTACTGGACACG': 55.02,
#  'GGGCCCTCTACTTGGAAGGA': 54.61,
#  'CACCACCCCTTCACCAACCT': 56.02,
#  'CCCGGGATTGGTTGCCTTCT': 56.55}

# %% [markdown]
# ### Generate primers with temperature restrictions

# %%
generator = PrimersGenerator(length=20, gc_percentage=0.3, min_temperature=35, max_temperature=40)
primers = generator.generate_primers()
primers
# Out:
# {'GATAGATACTACTCATAGTA': 38.7,
#  'TTACTATACACCATATATCC': 39.82,
#  'CTCCTATATATCCCTTTTTA': 39.88,
#  'CTAGAAAAGATCTAACTAAG': 39.53,
#  'CAGTACTTATAATAGAAACC': 39.86,
#  'TACTAAGATGTAGTTAGTAC': 39.88,
#  'AGAGAAGATGTAAGATATAG': 39.86,
#  'CACCTAATAGTGTAGTATAT': 39.83,
#  'CTATATTATAGTAAGGGGTA': 38.65,
#  'GTTAGTACTCGTTAATATAC': 39.97,
#  'TACATCCTATATAGATAACC': 39.16,
#  'GGAGGTAATGATATATTAAG': 39.21,
#  'CTATAGAGATAATTACCAAG': 38.93,
#  'AATATAGATAAAGAGGTAGG': 39.65,
#  'TATGTCACTATATGATAGAG': 39.68,
#  'GTTCCTGTCTCTATATATAT': 39.54,
#  'GGTAATTAAGTTACTTAGAG': 39.8,
#  'CTTTATATCTCCATTTATCC': 39.81,
#  'CTTCTGATATCTTCTTATTC': 39.95,
#  'GATAATAGGGAATAGATAGA': 39.1}

# %% [markdown]
# ### Generate a given number of primers

# %%
generator = PrimersGenerator(length=20, gc_percentage=0.5, number_of_primers=5)
primers = generator.generate_primers()
primers
# Out:
# {'TGTCCCACCCCTTCTTATCT': 51.3,
#  'GATCCGCGAAAAAACACACC': 52.73,
#  'GGTGTTTATATGCACGGGAC': 50.91,
#  'TGACTCCGAGGATGCAATCT': 52.63,
#  'CCAATATCTCCTTCGTTCCC': 49.56}

# %% [markdown]
# ### Give an impossible task

# %%
generator = PrimersGenerator(length=20, gc_percentage=0.5, min_temperature=0, max_temperature=5)
primers = generator.generate_primers()
primers
# Out:
# ---------------------------------------------------------------------------
# NoPrimersGeneratedError                   Traceback (most recent call last)
# <ipython-input-5-5a38b4350a86> in <module>
#       1 generator = PrimersGenerator(length=20, gc_percentage=0.5, min_temperature=0, max_temperature=5)
# ----> 2 primers = generator.generate_primers()
#       3 primers
#
# ~/PycharmProjects/prigen/prigen/generators.py in generate_primers(self, max_iterations)
#     165                             f"with standard deviation: {temperature_std}"
#     166
# --> 167             raise NoPrimersGeneratedError(error_message)
#     168
#     169         return primers
#
# NoPrimersGeneratedError: No primers were generated. Try to change parameters. Average melting temperature of generated primers: 51.79 with standard deviation: 1.54

# %% [markdown]
# ### Make sure primers are not found in some organism

# %%
generator = PrimersGenerator(
    length=20,
    gc_percentage=0.3,
    number_of_primers=100
)
primers = generator.generate_primers()

print(f"{len(primers)} primers generated")
# Out:
# 100 primers generated

# %% [markdown]
# #### Remote search against the whole NT database
#
# This will make sure that generated primers are not found in any known organism. Be careful, remote search for a huge number of primers takes a **long** time!

# %%
filtered_primers = filter_primers_by_blast(primers, remote=True)

print(f"{len(filtered_primers)} primers left")
# Out:
# 3 primers left

# %%
filtered_primers
# Out:
# {'AAATTCATCCACGAACTTAA': 44.9,
#  'GGACGAAAAAAAAACAAACA': 46.0,
#  'AGTAGAAGGGATTGTTATTA': 42.1}

# %% [markdown]
# #### Using a local Blast database:

# %%
HG_38_BLAST_DB_PATH = "/home/vladimir/Documents/Science/data/hg38_blast_db/hg38.fa"

# %%
generator = PrimersGenerator(
    length=20,
    gc_percentage=0.7,
    number_of_primers=10000, 
    min_temperature=55, 
    max_temperature=75
)
primers = generator.generate_primers()

print(f"{len(primers)} primers generated")
# Out:
# 10000 primers generated

# %%
not_human_primers = filter_primers_by_blast(primers, blast_db_path=HG_38_BLAST_DB_PATH)
print(f"{len(not_human_primers)} primers are not found in human genome")
# Out:
# 869 primers are not found in human genome

# %%
not_human_primers
# Out:
# {'GGACCCGCCTACGGGACAGA': 59.69,
#  'GGTCCGGTTACCGTGTCCGC': 59.77,
#  'AGCGTGCCTCGTTCGGGTGG': 61.75,
#  'ATGGGGGATGGGGGATGGGG': 59.36,
#  'CTATGCCCCCCCCCCAGCTT': 59.96,
#  'CTGCGCGGATTGCGAACGCC': 62.22,
#  'GGGACGTCGAGTGTGGGGTG': 59.08,
#  'CTCGCTTCGGGTGTAGGCGG': 59.57,
#  'TCTCTGCCCCCCCTGTCCGA': 60.76,
#  'TCATACCCCCCTCCCCCCAC': 58.63,
#  'TAGGAACCGGAGACGCCGGG': 60.04,
#  'GACCCAGTATCCGGAGCCGG': 58.37,
#  'CGTTGTCCCGCCGTTGCGCA': 63.45,
#  'CACGGCGCCGACCGACCAAA': 62.61,
#  'TCGGCAGGACGCTACGACCG': 60.99,
#  'GCGGCACCGCTAACGCACCA': 62.94,
#  'CAACCACCCCCCTCCCCCAA': 60.03,
#  'CCTCCACGCGCAAGAGGACC': 59.77,
#  'CGGGAGTAGCGAAGCCGTGG': 59.57,
#  'CATCCGCGGTAGGGACGCAG': 59.64,
#  'TGTCCGCTCTTACCCCCCCG': 59.97,
#  'GCGAGCCGTTATGTCGGCGG': 60.85,
#  'AAGATCCGCTGCGGCGGGTC': 61.89,
#  'GTGGCACCGGCGGAGTGAGA': 61.15,
#  'GGCTCGGTAGCGAGCGAACC': 59.91,
#  'CTCTTGGGGCGCGACGTGGT': 61.75,
#  'AGGGGCGGTAACGAGCGGAG': 60.66,
#  'GGAGCCATCACCGACCGGGA': 60.32,
#  'CCTTCTCGCGTTGGCGCGTG': 61.57,
#  'CTAGCTGCCGGCCGAGAACG': 59.91,
#  'GCAGGTCTGGGCGGACGGAA': 61.15,
#  'AAACCCGCGGGGGGAACGAC': 61.71,
#  'CGGCTCGGTAGGTCGTGCGT': 61.26,
#  'GGGGGTGCTCGAGCGTATCG': 59.36,
#  'CATCCCCCCCGTGATCCGGT': 60.04,
#  'TGCGTCACATCGACCGCGCG': 63.01,
#  'TAGCGAATCCGGCTCGCGGG': 61.4,
#  'CCCGCAACGCGGCACTCAAC': 61.78,
#  'GGCTATTGCTGCCGTCCGCC': 60.79,
#  'GTGTATCGCGGGGGTGGCAG': 59.84,
#  'AACCCCCACCCAACCCCCCA': 61.82,
#  'CTGCTACGGGTCGTCGCCGT': 61.26,
#  'CTTCCACCCCCCCCTTCCTC': 57.72,
#  'TCTCTTCCCCCCCCTCCCTC': 57.97,
#  'GGAGGAGGGGGGGGACAGTA': 57.97,
#  'CAAGACGACCCCCCCGGGAA': 60.18,
#  'CCCACGCTACCCGGTCGTTC': 59.5,
#  'CCCGGGCAAGTAGCGACCAC': 59.77,
#  'CCACCACGCGACGAGGGCAT': 61.82,
#  'CGCGGCGTCTGTTTCGCGTC': 61.87,
#  'CCGACTACCTACGCGGGGGA': 59.48,
#  'AACACGACCGCCGACTGGCG': 62.33,
#  'GCCGACGTGTGGTTCGGGTG': 60.58,
#  'ACACCACATCACGCGCGGGG': 62.36,
#  'ACACCGGACCGCAACCCCAC': 61.64,
#  'GGAGCCGGCACGTTCAAGGG': 60.32,
#  'GGCGCTAGTCGAGCGTCGGA': 61.05,
#  'GGCGACTCGCTACCGTACGG': 59.38,
#  'GCCTACGTGTCGCCGTCGAG': 59.91,
#  'GCATAGCCCGGCGCGACAAG': 61.12,
#  'GGTAGCGGCCTTAGGCGCGT': 61.62,
#  'AGGGCCGGCAACGCGCAAGA': 64.38,
#  'GGAGCACTAGGGCGACGGCA': 60.94,
#  'CTCCGACGCAACGCTCTCCG': 60.18,
#  'GGTTGGGGTAGCGCGGGTGA': 61.16,
#  'CGAGATTAGGCCGCGCAGGC': 60.58,
#  'CGCACCGGCACAAACGCGAG': 62.09,
#  'TTGTTCCGCCCTACGGGCCG': 61.49,
#  'CACCACGTCAAGCGCGGCTC': 61.24,
#  'GGGGCGATGCCTTTTGGCGG': 61.28,
#  'GGGGGCCTACGAGCGAGGAA': 60.04,
#  'ACGACACAGCCGACGACCCC': 61.14,
#  'GCCCGTCATTCGCCGCACCA': 62.7,
#  'GGAAGCACGAGGCGGCGAGT': 61.81,
#  'ACCCTGCGCACCGAAACCGC': 62.9,
#  'GCCGGCCGCTTCGTAGTCTC': 59.91,
#  'GCCGGATAGTCCCGGTGTCC': 58.65,
#  'TCGACGCAGACCGCAAGGCC': 62.08,
#  'GGACGTGTCGCTCGCACGCT': 62.37,
#  'TAGGATGGGGGATGGGGGGG': 58.39,
#  'TTTCCCCCGGCCCCCCAACA': 62.52,
#  'TGGTGCCCCGGCCGAATCTC': 61.23,
#  'GGCGGGGGTTCGATTGGGGT': 61.17,
#  'GAGGAGTCCCGCCTAGTCCG': 57.75,
#  'CACGATTCGGTCCCCGGGGA': 60.32,
#  'GCCCCTACTCGGTTACGCCC': 58.93,
#  'GCGGGCGTTCGTTTGCGCCT': 63.79,
#  'GCCACACAACCGCCGAACGG': 61.45,
#  'GGCCCACGTGTCGCTCGTTC': 60.65,
#  'GGACGCTAGAGCACGACGCG': 60.25,
#  'CGCCCGTTTTTAGCGCGGGC': 62.17,
#  'TCGAGGCTTGTCGGGCCGCT': 62.96,
#  'CCCCTAAGATCCGCGCCCTC': 58.72,
#  'GGAGCGTACAAGCCCCCCAG': 59.13,
#  'GCGTTTTCGCGAGGGCTCGG': 61.31,
#  'ACCCTAGCCGTTCGGGCGCA': 62.97,
#  'CGAGCCTCCTCACGATCGCC': 59.37,
#  'CGCTTTGCCGGTCGCCCCTT': 62.65,
#  'GGAGCGGCGATCGAAGGCAG': 60.25,
#  'CGCGGTATCACGGGCGAGAC': 59.98,
#  'CTGCGCTTTCGGTCGCGCTG': 61.88,
#  'GACCGAGACGTCGAGCGCGA': 61.31,
#  'GGGTCGGGGGGGAGTAGTGT': 58.95,
#  'GCCCGCGCTACGGGTGAGAT': 61.35,
#  'TGGTCGCGACTTCGGTGGGG': 61.14,
#  'TCCGGTCCGGTTCGTCGACC': 60.59,
#  'CTACGCCGGAACACCGGAGG': 59.22,
#  'ACGAGTACGCCCGGAGAGCG': 60.72,
#  'TGTTGCGCGTCGTCCTGGGC': 62.61,
#  'TCGCGGAGCTAGACGAGGCG': 60.79,
#  'CCCGGACCACTTCGCCCGAA': 61.15,
#  'GCGCTGCGTAGATAGGCGGG': 60.05,
#  'TCTAGGTTGGGGGGGGGCGT': 61.06,
#  'TCCCGAGCTCTGTCGGTGCG': 60.93,
#  'AGGGCACGAGGAACGGACCG': 60.87,
#  'AGGCGCCGAACCAAGCGCTG': 62.96,
#  'GCTTGCCGCCTCCGGTAGTC': 59.84,
#  'TGACCCCCCCCCGCTAATCC': 59.67,
#  'GCAGCACAGACGACGCCCGA': 62.07,
#  'GCCCCCCGCTTCGTCGTTGT': 62.03,
#  'TTTCCGGGGTCGTTGCGGGG': 61.71,
#  'CGGACCGACCCATTCGGCTC': 59.57,
#  'GAGACTAGCGGGACGCAGCG': 59.64,
#  'GCTTCGCGCGTCTCTTCCGC': 61.36,
#  'TGGGTCCGGTCGAGTCGTGG': 60.25,
#  'CTCTTACCCCGGGATGGGCC': 58.26,
#  'GTGGACGGAACAGGCGCGTC': 60.65,
#  'CCCGGTCGCTTTCGGACGGT': 61.48,
#  'GGCGTGTTGTTTCGCGCGCG': 63.21,
#  'CCGCAAGGCGACCCTACTCG': 59.57,
#  'CTGCTTCGGCGTGCCCTAGC': 60.45,
#  'TGCTCGGTCGGCGCTCCGAA': 63.25,
#  'AGGTTCGTTTGCCGCCCGGC': 62.92,
#  'TCCCCCCCAACCCCCATTCC': 59.81,
#  'CGAGGGGGCGTATCCGAGCA': 60.46,
#  'GGTGGGCTGGCGCGTTATGC': 61.33,
#  'AGGCCGGTAAGGGCGCGGTA': 62.43,
#  'CCACGTGTGGGTCGGTTCGC': 60.58,
#  'CGCATCCAGACGACCGACCC': 59.57,
#  'GTCCTCGCGGCGGTTCTCGT': 61.53,
#  'GCGACGCACCGACACAACCC': 61.18,
#  'GGGCACGACGAAAGAGGCGC': 60.98,
#  'CGCACAAACGCGAAGCCCGG': 62.1,
#  'ACACCCCCCCCCCCAAAACC': 60.62,
#  'GGCGGGTAATGTCGAGCGGG': 59.91,
#  'ACCTCATCGCGCCGGGGCTT': 63.32,
#  'CACCCCAAGCAGACGACGCG': 60.65,
#  'TCCCCCCCCCCCCCATTCTA': 59.8,
#  'CTTCCCCCTTCCCCCCCCTT': 59.14,
#  'GAGGGAAGCGTCACACGCGC': 60.98,
#  'GGGCCGGCGAAGCCGTACAT': 61.9,
#  'CCTCGTTGGTGCTCGCCGTG': 60.65,
#  'TGTCTTGTCGCACCGCCGCC': 62.61,
#  'CACGAACCCTTTCGCCGCGG': 61.25,
#  'CCCCATGACGGACGCTCGAC': 59.57,
#  'TGTTGCCTGCCGTCGGTCGC': 62.61,
#  'GGCGAGAGCCGGATAGGAGG': 58.17,
#  'GCCCTCATGCGGTACGCCGA': 61.62,
#  'GACGGTCCGGAGCTATGGCG': 59.36,
#  'GCGAGAGCGGACCTCGGGAA': 60.66,
#  'GGGCCACGCCCGTACAGAGA': 60.6,
#  'GTAAGAGGGGTACCGCGGGG': 58.29,
#  'GGCGATAGCCCGCGGGTGAA': 61.62,
#  'AGGAACGGGGGGGGGAGTAG': 58.65,
#  'TTGCTTTCGTCGCGCCCCCG': 62.94,
#  'CGACGCGGAAGGGGATAGCG': 59.71,
#  'GGCCGACCGAACCGGTAGAC': 59.23,
#  'CCCCCGGATACCGGGCTTAC': 58.35,
#  'GCCCGTTAACGGTACCGGCC': 60.11,
#  'GACGTCGCGGTCAGTGACGC': 60.71,
#  'CCCAGGCGCAAACGCTACCC': 60.66,
#  'GAGTACTAGCGCCCCGTCGC': 59.37,
#  'CGCACACCGCGGCAAACGAG': 62.09,
#  'GGGTTTGGTGCCGTCGGTCG': 60.59,
#  'CTCTCAACGCCGGGACAGGG': 59.14,
#  'CTCATGCCACGAGTCCGCCG': 60.18,
#  'GGAGCGGGGGGGGGATGTTT': 60.54,
#  'AGAGTGGGGGGGGGTGGAAG': 59.15,
#  'GCGCCGTGCCACGACAGAAG': 61.24,
#  'CTGGAAGTTCGTGCGGGGCC': 60.32,
#  'ATGGGGGCGTCGGTTCGCGT': 63.56,
#  'GGAGCGGCTGTCGACGAAGG': 59.84,
#  'CTAGGTCCTGCGCCGGTTGG': 59.49,
#  'CCCGTCGGCACGCCGGTTTA': 62.08,
#  'GCAACGATCGCCGCGTAGGG': 60.85,
#  'AAGCGGGGGAGGGGGGACAA': 61.64,
#  'AGCGCGGCGCGGAAGTGAAG': 62.99,
#  'CCGGCGCTTCGCCGCCTATA': 61.74,
#  'CGGGTTGTAGGGCCTACGCG': 59.57,
#  'GTGTCCGCGGGTGAGATGCC': 60.11,
#  'CAGGGGCCTATCGGCGAGAC': 58.73,
#  'TGGGCGTTACCCGGCTGTCG': 61.49,
#  'CCCAATCCAACGAGGCCCCG': 59.76,
#  'AGTTGGGGGGGGGTCGACTC': 59.53,
#  'CGAGGTTCATCCCGGTCGGG': 58.94,
#  'GTGTGTTCCCGCCGAGACGC': 60.65,
#  'GAGAGTCGTCGCGGTGAGGG': 58.96,
#  'GGGTGGTTGCCGTGCGCGTT': 63.43,
#  'ACGCTCGGCGGCGTATCGGT': 63.36,
#  'CCGCCACGACACGCCACAAG': 61.18,
#  'CAGGACGGTGGTCTCGCACG': 59.78,
#  'TGGTCCGGACGGACGGGGTT': 61.95,
#  'ATGCCCGTCCGGCGGTCGAT': 63.09,
#  'GGGCGTGGCGCAACAAGGTC': 61.47,
#  'GAGAGAGGGGGGGGGAGGAA': 57.97,
#  'CCATCGTGTCCGTCCGTGGC': 60.11,
#  'TACCCCCCCCACCCCCAACT': 60.63,
#  'CACAAGCGAAGCCGCCCCCA': 62.32,
#  'AGGAGCACCTACGCGACCGG': 60.66,
#  'CCCTCTCTTCGTACCGGCCC': 58.3,
#  'GGTATCGCCCGCTTACGGCC': 59.98,
#  'GCCAGCGTCGCGGTGTATGG': 60.78,
#  'ATAGCTTCGGTCGCGGGGGG': 60.74,
#  'GGGCGATTGGTGCGCGTGTG': 61.85,
#  'GTAACGCCGGGACGACCCGT': 61.2,
#  'ATCGGAGACCCCCCCGACAG': 59.4,
#  'AGCCGAACCGCCCGAACCGA': 63.22,
#  'GTCGAGAACCGACGCCCGAC': 59.85,
#  'CTACCCGTCGAACCGGTCGC': 59.58,
#  'GTGAGCTCTCGCCGCTTGCG': 61.04,
#  'GGCAAACGACACCGGCCCAC': 61.13,
#  'GTGCTTGGGGGGGGAGTCGT': 60.46,
#  'CCCCGGAATCCGACACCCCT': 59.97,
#  'TGAGAGGGGGGTTGGGGGGT': 60.63,
#  'CCTTTTCCCCCCCCTCCTCC': 57.7,
#  'GCCCTAGACGCGACACGGAC': 59.57,
#  'CACTACGCCACCGGACACGG': 59.77,
#  'ACGAGCGGCCCAAACGAGGC': 62.36,
#  'GAGTCCTCGCGCAGGCAGAC': 59.84,
#  'GAAGAGGGGGTGGGGGGGAA': 59.15,
#  'CCCGGCTAAGCACCGCGACA': 61.82,
#  'GAGAGGTCGGCGACCGGACA': 60.32,
#  'AGGCGCGTCGTTCGTGGCGT': 64.33,
#  'CCAAGACGCGGAACGCCCAC': 60.92,
#  'GAACGGCGTACAGCGGCAGC': 61.31,
#  'GCCCCCATCCCCCCCCAATT': 60.55,
#  'CAACCACCCCCCCCCAGACA': 60.03,
#  'ACGCGGACGGCAAACCCCCA': 63.74,
#  'CCTAATCGAACGGGGGCCGC': 59.91,
#  'TTCCTCCCCCCCCCTCCTTC': 58.55,
#  'ACCGAACCGAACGCGCAGCG': 63.22,
#  'TTCGCCCCGTCCCGGTACCT': 61.74,
#  'TCCAGACCGGAGCGCCCCAA': 62.31,
#  'CTTGTTGCGGCGTTGCCGCC': 62.64,
#  'ACGACGGACACCGCCAGGAG': 60.87,
#  'GCGCACGCGGCGGAAAAGCA': 64.35,
#  'TCCGTGCGCTGTTGCTCGCG': 63.22,
#  'CCTCCCGCTCGTACCACGTC': 58.96,
#  'GGCGATTAGGGGGGGGGAAG': 58.25,
#  'TGTGGCCGTGAGCGCTACGC': 62.4,
#  'ATGACCGTCGTGCGGGCCAG': 61.82,
#  'GGGGGTGCGTCGTTTCGGTG': 60.59,
#  'CCATCCTCAACCGTCGCCCG': 59.84,
#  'TCGCGGCAACGATCCACCCC': 61.83,
#  'AGGCGGAACGCCAGACCGAC': 61.48,
#  'GGACGTTCCGACCGAGTGCG': 60.11,
#  'TTGCGCCCCCCCTTGATCCG': 61.52,
#  'TGGTTCGGGGGGGGGTTTGC': 61.33,
#  'GTTGTTGGGGCGTCGGCGAG': 60.92,
#  'GACGCCCAGAACGCGTGTCC': 60.65,
#  'CCACTGCGCCAACCGACACG': 61.18,
#  'GCGCGTAACGCCGTTCCTGC': 61.89,
#  'TCCGCGTTTTCGCCGGCTCG': 62.97,
#  'TGCGTAGCCGTGCCCGTTCG': 62.39,
#  'TGGTTGGGGGGGGGTAGGTC': 59.15,
#  'CGAGGGTATCGGTACCCCGC': 58.46,
#  'GCAAGACGACCGGACGCAGG': 60.38,
#  'TTGTTGGGGGTTGGGGGGGG': 60.62,
#  'CACGCCTGACGGCGTCACAC': 60.91,
#  'GAGCCCGCATTCGTGCCAGC': 61.33,
#  'GCGGTTCGCCGGAGTACGGA': 61.27,
#  'CGACTGACCGAACCCGCCGT': 61.47,
#  'TCTAGCAGACCCGCGTCCGC': 61.0,
#  'CTGGTCGGGCGTATGTGGCC': 59.84,
#  'TTTTGTGGGGGGTGGGGGGG': 60.62,
#  'GCTGCCGAGTAACGCGAGCG': 61.1,
#  'AGTCTGGGGGGGGGCAGCAA': 61.94,
#  'TCTCGTCGGCGGTTGTCCGG': 61.2,
#  'CACGCCGGAGCACCAACCCA': 61.98,
#  'CACAGCACACGCGGAGTGCC': 61.19,
#  'CACGAACTGCCGAGGACGGC': 60.38,
#  'CAGCGACGAGCACCTTCCCG': 60.11,
#  'TAGGCGCGGTGCCGGTTGTG': 62.36,
#  'CCGCACTGCGCCGAATTGCC': 62.18,
#  'CACGCTCTACCAGCGTCCGC': 60.18,
#  'GCGACCCGAAAGGTGGCGGT': 62.03,
#  'ACAGCACGCGCTCGTCCCCA': 63.48,
#  'CGGAGAACGCAGCGTCGTGG': 60.71,
#  'GATCACGCCGAACACGGGGG': 60.11,
#  'CGAGAGCGCGAGACGCCACA': 61.85,
#  'TTTCCCCTTCCCCCCTCCCC': 59.14,
#  'GTAACCAGGAACGCGCCGGG': 60.38,
#  'GCGGCCGAGCGAAATCGGAC': 61.11,
#  'GGTGCGACTTGGTCGGGCTG': 60.32,
#  'CATCGAGGGGCGGACTGCGA': 61.01,
#  'TGGGGGTTGGGGGGTGTGTG': 60.61,
#  'CCTACTCTACGCCCGGCCTC': 58.1,
#  'GCTTGGAGCGCTCCGCCCAT': 62.18,
#  'CCCGCAGCGTCACTAGGTCG': 59.57,
#  'CCTCTCCGCGACGACCCTTC': 58.95,
#  'CCGCGGCCTGTTCGTTGCTC': 61.25,
#  'GGGAGTGGCACGACGACGCA': 61.74,
#  'GATCGCGGCCCGTCGTGATG': 60.58,
#  'CGTGCGGACCGTACGGGAGT': 60.93,
#  'CTACCCCCCCTCCCCCTTTC': 57.12,
#  'GGTCAGCGGGCAACACGAGC': 60.92,
#  'GCAGGAGACGGACCCACCGA': 60.25,
#  'AGACCTTCGGTGGCCGGCGT': 62.9,
#  'ATACCGCCGAACCGAGCGCG': 62.25,
#  'CACCGGCGAAACCATCGGCG': 61.32,
#  'TCCAATCCCCCCTCCCCCTC': 58.63,
#  'ACCCGCCCGCCGTACCCAAT': 63.0,
#  'AAGCCCAACGCGACCGAGCG': 62.67,
#  'CCCCCCGCCTATACCTTCGC': 58.71,
#  'GGTTGTGCGTGGTCCGCTGG': 60.86,
#  'TGCGTCCGCGACCTCTCTGG': 60.93,
#  'CGCCCGCGCTCTATCCTAGG': 58.88,
#  'GTGGTGCGCGGTTTGCCGGT': 63.43,
#  'TACCGTGACCCGCGAACGGC': 61.8,
#  'GGTGTAGGGGGGGGGAAGGA': 58.56,
#  'CTTCGTGCGCGGCAGTTGGG': 61.52,
#  'TGTAGCCCCCCCCCCATAGC': 59.38,
#  'AGCAAGGCGCGGGAGACGAC': 61.81,
#  'GGCAGAATCGCGAGGGGGAG': 59.28,
#  'CAACCGGCGGAGGACCGACA': 61.14,
#  'GCCCGGTAAGCGACAAGGGG': 59.77,
#  'GCGAAGCATCGCGCGGACAG': 61.69,
#  'GGCGTAGATGGGGGACGCGA': 60.73,
#  'CCGGCCCGCGACAGAAGTCA': 61.48,
#  'TGGGTATCGCTCGCGCCGCT': 63.39,
#  'AGGTCGAATGCGCGGCGCTG': 63.05,
#  'CTTCTCGCGGTGCGTACCCG': 60.18,
#  'GTCACGGTTGCGCGCTCCGA': 62.65,
#  'GTGGGGGTTGGGGGGTGTCT': 60.03,
#  'GCGACAGCCCGCAACGAGAG': 60.71,
#  'CTACTCGCGGTTCGGCGAGG': 59.64,
#  'ACAACACCCCCGCCGACGAC': 61.69,
#  'CTCCCCGAACAGTGGCGGTG': 59.7,
#  'TCCGTAGCGCCGATCTGGCC': 61.07,
#  'GGGCGGGTTCCGTTTGGTCG': 60.59,
#  'GCCCGGTAAAGGCGTGCACG': 61.25,
#  'CTTGCGCGAGGTCCGACTCC': 59.84,
#  'AGCACGGCGCCATGTCGTCG': 62.72,
#  'CAGCCCAACGCGTCGCAACG': 62.09,
#  'GGCAATTAGCACGCGCCGGC': 62.24,
#  'TGGCGGTAACGGCCGGTTGG': 62.04,
#  'GAACAAGCGCGGTGACGGGC': 61.51,
#  'GGACCGGCGACCTGCGTAAG': 59.84,
#  'AGCCAATGCGACACGCGCGG': 63.58,
#  'CAGGTCGCATCGTCGTGCCC': 60.45,
#  'TGTGTCGTGCGTTCGCGCCC': 63.17,
#  'TTCGTCGGCGCAGGGCACGT': 64.05,
#  'GGTTCGAACCGCGGTAGGGC': 60.11,
#  'CCTCCGGCACGACGCTCAGA': 60.93,
#  'ACCACGCCACCGAACAGCCG': 62.29,
#  'TCCCCCCCTCCCCCCTTTCT': 60.03,
#  'GCCCACAACGCGGGAGAGTG': 60.32,
#  'ACGTGCCCCGCTGGTTCGTG': 62.29,
#  'CGCGGTCGGCGCTCGTTTGT': 63.22,
#  'AGAAAGGGGGGGGGTGGGGT': 60.93,
#  'GCGGGTGACGATCGCGTGGT': 62.13,
#  'AACAGACGGGGGGGTGCCAG': 60.75,
#  'CGTCAGAGACGGACGACCGC': 59.58,
#  'ACTCCCCGAACTCCGCCGAC': 60.6,
#  'GGGACGCGGACGAAGGGATG': 59.57,
#  'AAGCGACCAACGGCGCACGG': 63.19,
#  'GGCGTAGCGACCAAGCCACG': 60.72,
#  'CGGAGCGTGGCTTACCCCCA': 60.88,
#  'CTCGTCCGTTGGGGTACCCG': 58.87,
#  'GGCTCGCAGCGCTAAACCCG': 61.05,
#  'CTCAGGCTCAACCGCCGAGG': 59.49,
#  'GGGCGCAAAAACGGCGAGGG': 61.8,
#  'TGATCCCGTTCCGCCCCTGC': 61.23,
#  'CCCCTCCGCCGCCTACTACT': 59.47,
#  'GCTCCGGGGGTACGTCGTCT': 60.04,
#  'GCCACCGGCGCACCGAAGAA': 62.63,
#  'AAGGCGCCCGAACACCGAGC': 62.36,
#  'CTCCGGTCGGCGTCCCTTTC': 59.5,
#  'CCTGCCGTTTTGCGTGGGGG': 61.14,
#  'GAGCGAACCCCCCCCCTGAA': 60.18,
#  'CTCACGCCCCCCCTAACACC': 58.77,
#  'ACCCGGGCGTACGACGTGTG': 61.47,
#  'TCGGACCGCCGGTAAGCCCA': 62.36,
#  'TGCGCGTTGCAATGGGGCGC': 64.4,
#  'GGCCAAATCCCGTCGCGGCA': 62.71,
#  'GGAGGAACGCAACCCGCCAG': 60.32,
#  'AACCCCCCCCGACATCGGGA': 61.41,
#  'GGGGTTACGCTGGCTCGGAG': 59.22,
#  'CCCGGAGCCCGCTAACAGTC': 59.22,
#  'GAGGGGGGTAGGGGGAAGTC': 56.84,
#  'TCGTCCGCTTTCGTCCGGCC': 61.81,
#  'GGCGGCGGGAATGTCACTCG': 60.45,
#  'ATTGGGCGATACGCGGCGGG': 62.29,
#  'CCTCATCCCGTTCGCCCCGA': 60.67,
#  'GAACAGCGCACGCGGCGAGA': 62.96,
#  'TTGTTGGGGGGGGGTGAGGG': 60.03,
#  'CCCCGTCCCCCCCGATCTTT': 59.96,
#  'ACACTAGTCCGCACCCCGCC': 60.88,
#  'TGGGGCGATACGTTGGCGGG': 61.56,
#  'CCGACCTGCCGACAACGCCA': 62.02,
#  'GGTCACGCGCGCTCAAGCCA': 62.93,
#  'CAACACCCGACGAGACGCGG': 60.38,
#  'CTCCCCCCTCCCCCCTTTTC': 57.7,
#  'CCCCCCAAACCCCCCCACAA': 60.62,
#  'GGCTGTCGTTCGCCGGTTGC': 61.51,
#  'GTGCGCGGGTTGGTTGTCCC': 61.13,
#  'ATCTCTCCCCCCCCTCCTCC': 57.74,
#  'CCCCCCATCGGCCGTACACA': 60.6,
#  'CCTGTCTCGGCGTTACCCGC': 59.84,
#  'GGGCCGGAACAAACGGGGGA': 61.38,
#  'CCAACGACGCAAGGAGCCGC': 61.25,
#  'CGGGGCTCAACGGCGTATGG': 60.18,
#  'GCCACCCGACCGGATAGGAC': 58.65,
#  'GGGGGGTTTTTCGGGGGGTG': 59.54,
#  'CGTGCTTTCGGGCGTCCTCG': 60.71,
#  'TCAATGCGCCCCCCCGGTCA': 62.95,
#  'CACAGGGCCGCAACGCCGAA': 62.9,
#  'TGCCACCCCCCCCACTTTCG': 61.04,
#  'GGGTCCGAGGAAACGGCGTG': 60.04,
#  'CATTGCGTAGCCGCGGACGG': 61.11,
#  'ACAGTCGCCGGCAACGGAGG': 61.75,
#  'CGTCGACCACCGTGTTCGCG': 60.97,
#  'CCGTCAACACCGCAACCCCC': 60.52,
#  'GGCAAGCGGCCGACACACAC': 61.46,
#  'ACGGCGGGGGGGGGTGTTAT': 62.06,
#  'GACACACGGGTAACGCGGGG': 60.04,
#  'CGGTCGCCGGCCCTATAAGG': 59.08,
#  'ACCTCCCGCTTGTCGGTGGG': 60.81,
#  'GGGAAGCCGAACCGAGCGAG': 59.84,
#  'GTTTGGGGGGGGGGGGTTTG': 59.46,
#  'ACCCCCCCACCCCCTCATCA': 60.7,
#  'CCCGATACAACCCCCCCCCT': 59.3,
#  'AAGCTTCGGCGCGCGGTTGG': 63.53,
#  'CCGCCCCGTTACCGATACCC': 59.01,
#  'GGCGACACGCGGACTCACAG': 60.38,
#  'GTGCGCGCTTGTTGGTGGGG': 61.73,
#  'AAACGGAGGCCCCCCCTCCA': 61.64,
#  'GGGATACGGCGGAGTCGGAG': 58.46,
#  'ACCGCCCGGACCAAACACCC': 61.65,
#  'ACGCACGGACGTTACCGGCG': 62.38,
#  'TGAAGGGGGGAGTGGGGGGT': 60.63,
#  'CCGTCGCTAACCTAGCGCCG': 59.98,
#  'CCGTGCGCACGAAACCCCCA': 62.57,
#  'GGGATACCGGAGCCGGGTTC': 58.64,
#  'CGCTCCGGTTCGCGCTTGCT': 62.99,
#  'AGGCACAAACCGCCGAGCCC': 62.33,
#  'TGACTAGGCCGCGTGCCACG': 61.81,
#  'GACACGGGGCGTTTGGCGCT': 62.9,
#  'GACGAGCTCCGCCTGATCGG': 59.37,
#  'AGCCAACTCGCCGGGAGCCA': 62.93,
#  'GAGCCGACGGAGCACGGATG': 59.91,
#  'TCGCTTCCCCCCCCCGTTCA': 61.98,
#  'CCGGCCCAGTCATCGACCTC': 58.94,
#  'GCGATTGCGGTCAAGCCCCG': 61.32,
#  'GAGCGGTCGTAACGGGGACG': 59.58,
#  'CCGGAACGTCTCGTGCGTCG': 60.44,
#  'CGACCTGTATCGGCCCTCCC': 58.37,
#  'CGGACGGTGGCGTGCGTACT': 61.8,
#  'GGGGGGCGAACTTCGGTGGA': 60.81,
#  'GAGAGCGCAAACGCGACGGG': 61.3,
#  'ACCAACCCCCCACCCCCCAA': 61.82,
#  'CCACCCGTCAGAGCGCGAAC': 60.38,
#  'GGTCGCGGGTTATCGGGTGC': 60.18,
#  'CCCGCCCTCAGAACGCGTAC': 59.84,
#  'CTGCCGGCTTTTCGCGCCTG': 61.85,
#  'TCCGCTTGCGCCCTCGTGGT': 63.5,
#  'ACGGCACCGCGGAAAAGGCG': 63.21,
#  'TACGACCGGCCGAACCGCAG': 61.54,
#  'CACCGAACCCCCCCCCCATA': 59.6,
#  'GACGCTTCGTCCACGCGGTG': 60.97,
#  'ACGACGGGTCGCGATAGCCG': 61.39,
#  'ATCACCCCCCCCCCACCACA': 61.29,
#  'CCCCCCTTACGACGAGGCCA': 59.97,
#  'GGACGCGGACCAAAACCGCC': 61.19,
#  'GTCCGTGTCGGATGCTCGGG': 59.57,
#  'GAGGCGGCGAGGGTAGACCT': 59.76,
#  'CTTGCCGCGCACGTCTCGCA': 63.22,
#  'GCGCCGGTGGACTCGACGAT': 61.6,
#  'CGGCCTAGGGACGACGTTGG': 59.22,
#  'GGGGGGAGGGATGGGGGATA': 58.09,
#  'GATTTGGGGGGGTGGGGGTG': 58.95,
#  'GGACGCGTTACCGCTGGCTG': 60.72,
#  'GGCGAACCCATCGGCGGGTA': 61.29,
#  'AGCGGAACTGACGGAGGGGG': 60.25,
#  'GTCCCGCGTCGTGACTAGGG': 58.96,
#  'TATAGCGGGGGAGGGGGGCT': 60.33,
#  'CGGCAATACGGGCGCCAACC': 61.33,
#  'GTTGGGCGTATGGCGGCCGT': 62.44,
#  'CGCAAATCCACCGCCGTCCG': 61.32,
#  'AGACTAGGGGGGGAAGGGGG': 57.95,
#  'ACGAGCGGAATCCGCGAGCG': 62.24,
#  'CCTCGCTAACACCGGGGACC': 58.86,
#  'TCCGCGGATACCCTCGGGTC': 59.83,
#  'TCCGCCTTCGGCTCGCAGCA': 63.55,
#  'TGAGTAGCGTCGTCGGGCGG': 60.99,
#  'CGGAGATCGAACCGGGGTGG': 58.94,
#  'CGCTTTCAGAGCGACCGGGC': 60.72,
#  'CCCCTAGGTATCGCACGGGC': 58.72,
#  'GGTCGATGCCAGTCGGCGTG': 60.45,
#  'AGGACAGGGGGGGGAGGGAA': 60.03,
#  'CCAACCCGAGTGGCGACCCT': 60.81,
#  'GTCCTAAACGGGCCCGCCCA': 61.16,
#  'ACAATGACGCCCCGACGGCC': 62.1,
#  'AGTCCGCCCTACCATCGGCG': 60.73,
#  'ACCAACGCAACCGGGGCAGC': 62.87,
#  'GGAACATTCGCCCAGGGGGC': 60.04,
#  'TCTGCCGCAGGTTACGCGCG': 62.71,
#  'CAGGAGTCGATGCCCGGGGT': 60.32,
#  'CCCGGATAGCGGCCGAAGTC': 59.36,
#  'GTGTGAGGGGGGGGTTGGAG': 58.32,
#  'CAACTCGCCCCAAGGCGGAG': 60.04,
#  'AAGGGCGACGTCGAGCGACG': 61.84,
#  'ACCTGTGTCGCGCCACGCGT': 64.3,
#  'AGCCGTACCGCTCAACCCGC': 61.82,
#  'GCGGCGTTGCGTTCGGACAC': 62.08,
#  'GCACGGCCCGAGGATACGAC': 59.64,
#  'AGAGGGGGGGGGGGGTAGAA': 59.42,
#  'CACGCAATACGGCGGCACGC': 62.21,
#  'CCGCCTTACGCCGTCTTCGC': 60.78,
#  'AGAAGGGGGGAGGGGGAGAG': 57.96,
#  'CGCCCGCTTCCGAAGCGTAG': 60.51,
#  'GGTGAAGGGGGGGGGTGATG': 58.38,
#  'TGTGGGGGGTGGGGGTTGTG': 60.61,
#  'TGCCTGCCGTTGCGTCCTGG': 62.31,
#  'TCTCTCCCCCCCCCCATCCT': 59.5,
#  'CGCGTATACGGCGGGGCGAA': 61.99,
#  'CGCCGACCGACCAACGCGAA': 62.64,
#  'GTGTTCGGTCCGTCTGCCGG': 60.04,
#  'CCGCAAAAGCGACCGACGCC': 61.83,
#  'GGGGAACGACCCGCAGAAGG': 59.42,
#  'TCCTTCTTCGTCGCCGCCCC': 61.21,
#  'CCCCTTACGCGCCTCCTGTC': 59.22,
#  'CCCCTACGTTACTCGCGGCC': 59.29,
#  'CCACTCGCGTCGCTCGTTGC': 61.3,
#  'CCCCATCCCCCCCCACAACT': 59.81,
#  'GAGGGAAAACGCGCGCGAGG': 61.31,
#  'GAACTGCCCGGAGTACCGCG': 59.84,
#  'AGAGGGCGTCAACTGGCCCG': 61.16,
#  'CCCACCGGGTGAAGCGGAGA': 60.53,
#  'CCCCGCAGCCCGTATCCATG': 59.63,
#  'CGTTGTCGGCGGTCTGGACG': 60.38,
#  'CGGGTGCTCGCGCCACATTC': 61.32,
#  'TGGTCCCGTCTACCGGGCGT': 61.73,
#  'TGTCCGGAGGCGCACCGTCT': 62.61,
#  'GTGACAACGCGCGCGACAGG': 61.81,
#  'GTGGTATGTCGGTGCCGCCG': 60.45,
#  'ACGCGCGGCGCGATATGTGG': 63.16,
#  'GGCGCTCGCCGAAAGACAGG': 60.72,
#  'CGCGACAGCGCATAACGCGG': 62.0,
#  'GGCGCCTGTTGCGTTCGTCG': 61.82,
#  'GCCCCACTAGCGACCAGTCC': 58.86,
#  'CCCCGTGTTAAGCCGCCGAC': 60.38,
#  'CACACACCCCCCCCAACCAC': 59.47,
#  'CCGCGCGCTCTCTAAGGCGT': 61.93,
#  'TTTCCCCCCCGTCCGACTCC': 59.9,
#  'GTGCGTGGGGTCGTCGCTAC': 60.11,
#  'GGTTGGTTGTACGGGGGGGG': 58.97,
#  'GGCGACGTCCCGCGTATCAC': 60.25,
#  'AGGCCGCGCCAACGCAAGTG': 63.49,
#  'CAGACCGCGCAACCCTCGCA': 62.35,
#  'TGTGATCGCGTCGCCCCGGT': 63.27,
#  'GGTACTTGCGCATCGCGGCG': 61.69,
#  'ATTGCGCCACGTACCCCGCC': 62.44,
#  'CCGGAGGATAGCCCGAAGGG': 58.07,
#  'TACAGGCGCGGCGACAGGAG': 61.27,
#  'ACGGCGAGTCGTGGTTGGCG': 62.33,
#  'TTGTTCGGGTCGCGCCGTCC': 62.34,
#  'CGGAGTACTCGTGCGCACCC': 59.84,
#  'CCGTGGACGGTTGCGCAAGC': 61.78,
#  'ACGACACCCCCCCCTCCGAA': 61.33,
#  'CTCGTTTCGCCCGTTCGGCC': 60.98,
#  'TGTGGGGGGGATGGGGGATG': 59.59,
#  'CACACCAACGGTACGGGGGG': 59.35,
#  'GGAGCATAGAACGGGGCGGC': 59.91,
#  'ACCTTAGGGCGCCGCAAGCC': 62.12,
#  'GGGAGACGGATCGGTAGCGG': 58.46,
#  'CGCAAGCCCCCCCACGAACT': 61.72,
#  'CCGCCGTTTCGATGCTCCCG': 60.78,
#  'CACGCGAATACAGCGCGGGG': 61.11,
#  'TCGTGTCCGTTCGCCCGCTG': 62.06,
#  'CGTCCACGCCGATGCCAACC': 60.99,
#  'CCCCCGCGACCACCTTCGTT': 61.43,
#  'TGCGACGGGTTACGACCGCG': 62.11,
#  'GCCGACGAATGGCGGGTCGT': 62.14,
#  'TCGCGGGGTAGTGCCGGTAG': 60.39,
#  'ATGCATGCCCGCAAGCGGCG': 63.96,
#  'TCGCAGTTTCGCGGTGCGGC': 63.5,
#  'AGGCAACGAGCGAGGACGGC': 61.81,
#  'TTTCCCCCCTTCCCCCTCCC': 59.14,
#  'TCGTTACCAGCCCGACGGCC': 61.21,
#  'TCGAGACGTGCGTGCCGAGG': 61.52,
#  'CCCGGTGTCCTAGCTCGGTC': 58.31,
#  'GGGGGTACGACGCAAGGGGT': 60.53,
#  'AAACACCCCCCCCCCCACAC': 60.62,
#  'GGCGATTCGCCTTGCGGCGA': 63.06,
#  'ACCCGAGCGCAACGTACCCC': 61.49,
#  'GACGGAAACCTCGTCGCCCG': 60.11,
#  'CCCACGGACGACCAAGCGAG': 59.77,
#  'CGCTCAATTCGGCGCAGCCC': 61.65,
#  'GGGCCGAAAGCGGCAAAGCG': 62.12,
#  'GCGCCGAGCCGCATTACGAG': 61.17,
#  'GCCGTCCGATCTGTCGCCTG': 59.91,
#  'CCGAACGACCGCGAGAGGAC': 59.58,
#  'TCGCCGTTCGTTTGCCGGGC': 63.2,
#  'TTGCGGGGGGGATATGCGGC': 61.65,
#  'GGCCGTCGGTTGTGAACCGG': 60.59,
#  'AGTCCGACACCACCACGGCG': 61.41,
#  'CCCAAATCCGTCCGGCGCCA': 62.11,
#  'GGTGTTGCGTCCCGGCTCGT': 62.02,
#  'CCTCGACTCGCGACGCATCC': 59.98,
#  'GGGCGCATAGGGGAACTCGC': 59.91,
#  'TGGTTCGCGCGGGTTTGGGG': 62.59,
#  'CACCCGTCGCGGTGCAAACC': 61.45,
#  'AGAAGCGGGGGGGGGGAGAA': 61.06,
#  'CCTGCCCATTCCGGCGCGTA': 61.9,
#  'GCAGGGAATCGCCGCGCCAT': 62.84,
#  'CCAGTCCCGACGCCTACCCA': 59.97,
#  'CCGACACAGCTCGCCACGAC': 60.38,
#  'GAGCCCAACGGCGTAGACGG': 59.84,
#  'GCGTTCCGTGGCTTACCCGG': 60.38,
#  'GGGCGTTGGACGGTGTTCGG': 60.59,
#  'ACTCTGGTTCGTCGGGCCCC': 60.53,
#  'CCGCTCTTGACGCCGGCTTC': 60.72,
#  'CGACCGACGCAACCAACCCC': 60.59,
#  'GACGCACCGGCAGTTCTCGC': 60.98,
#  'GCGCCGACAAGGAACGGCGA': 62.66,
#  'CTAGTCGGTCGCGTTGGCGC': 60.78,
#  'CGGAGCGTGCCGGATACGCA': 61.93,
#  'GACCTGCGTCCCGTAAGCCC': 59.49,
#  'CGCGAGCGCAGTTTTCCCGC': 62.15,
#  'AGCGGGTTGTCCGCTCGGTC': 61.48,
#  'CACGCGCACCCTAACTCGCC': 60.72,
#  'GGATCGGTGGGCGATGCGGT': 61.63,
#  'GTCACCGCCCCGTACCGGTT': 61.15,
#  'TTGCGGCGTTGGGCTTCGCG': 63.78,
#  'TGCGGCGAGCACGGTAAGGG': 61.82,
#  'CTGCTTCTCGACCGGTCCCG': 59.23,
#  'CACGTGCCGTCGCGCCAAAC': 62.34,
#  'CCATCGGCGCGACAGTCCTG': 60.18,
#  'GCAGCCGCTACTGGTGCCCT': 61.5,
#  'CCGTACGCGGTACGGGTCTG': 59.31,
#  'GGGGGACGCTGCGTGTAGTG': 59.77,
#  'CTCACGCGAACCTCGCGTCC': 60.45,
#  'ACGACAAATCGGGGCCGCGC': 63.01,
#  'CCCGTTCGGCCTCGAAGACG': 59.84,
#  'CTTAACCCCCCGCCCCCTCA': 59.89,
#  'TCGCGCACCGTCGCTTTCCC': 62.66,
#  'CCGAAAACCACCGGACGCCG': 60.92,
#  'TGGGGGTGTTCGCTCGGGGA': 61.96,
#  'ACATGGGGCCGCCGTAGGTC': 60.95,
#  'CCTAGCTCGCCGTCTGCGCT': 61.34,
#  'CGGGACGCGTTAAGGGGGTC': 59.49,
#  'AGCGCACCCAAAGCGCACGC': 64.06,
#  'CAAACCCCCCCCCCGACCTA': 59.53,
#  'GAGGGGGGATAAGGGGGGGT': 58.32,
#  'TCGTCGGCTCGCGCTTGCGT': 64.37,
#  'CGACCTACGCACGCCCTCAC': 59.84,
#  'CCGCCACCTCAATCGCTCCC': 59.84,
#  'CCGCACAAACCGATGGGCGC': 61.86,
#  'TGATGGGGGGGGGGGGGTTT': 61.31,
#  'CCCATGCTCGTCGGGCACAC': 60.38,
#  'GGGAGACGCGTCACGAGACC': 59.23,
#  'GCCAAGCCACCGACGGACCA': 61.7,
#  'ATACCGCGACCGGACACGCG': 61.92,
#  'GGCAACGGTCGTGTGGCGTG': 61.45,
#  'AACACGTGCGACGGGCGTGC': 63.43,
#  'CTACCCTTCGCGACGGGCGA': 61.0,
#  'CGCGCACCCCGTTTAACCGG': 61.25,
#  'GGGGATAGTTAGGCGGGGGC': 58.33,
#  'GCGAGCTGTAACGCGGGCTG': 61.05,
#  'CCCCGGTCTGCGCGCTTGTT': 62.63,
#  'ATGGGGGGTGGGGGTGGTGT': 61.59,
#  'CCATACCCCCCCCCTCACCA': 58.93,
#  'CACCACCCCCCCCCAACACA': 60.61,
#  'CTGCGTTCGGGTTGCGTGGC': 61.78,
#  'GGGGGCGGTATTCGGTCACG': 59.56,
#  'CGGTTGCGGCGATCCGTGTG': 61.31,
#  'CACAAGACCCCTCCGCCGCA': 61.43,
#  'TAGCGCGCGTGCGGTAGGAG': 61.65,
#  'TAACGCCCGGCGACGGAGAG': 61.0,
#  'GGTGATGGGGGGGTTCGGAG': 58.48,
#  'CATGATCCGGCGCACGACGG': 60.85,
#  'GGGGTCGGAGGCGTGGTGTA': 60.25,
#  'CCGCCTACACCGCCAATCCG': 60.18,
#  'CGTGGAGCGGCAACCGTTCG': 61.24,
#  'GACACCCCTAGGCCGATGGC': 58.92,
#  'CAAATCCCCCCCCCTTCCCC': 58.36,
#  'CCGCGCTCGCAAACAGGACG': 61.57,
#  'GCGCTCCGTTGACGACGACG': 61.03,
#  'CCGTACCCCCCCCCTAAACC': 57.81,
#  'CCCGTTTATCGCGCCCCCGT': 61.9,
#  'CGGCGCCGTTCGTTCTTCGC': 61.88,
#  'AAGGCGACGAAGCGCGGTGC': 63.25,
#  'CCCCCGACCTTAAACCCCCC': 58.39,
#  'GTCGCCGTGTAGCTTCGGCC': 60.45,
#  'ACCCCCCTCCCCCCCTAAAC': 58.84,
#  'CCGTGCTTCGGGCACGTCAC': 60.92,
#  'CCGCCGGCAGGTTACGCGTA': 61.87,
#  'CAAACCCCCCCCCCACCACA': 60.62,
#  'CGAGACACCGACCTCGAGGG': 58.34,
#  'CCGTGCGAATACCCGTGCGG': 60.78,
#  'GTTCCCGGATAGGGCCCCTC': 57.97,
#  'CCCAAACCCCCCCTCGACGA': 60.18,
#  'AAACCGCGGGCCACGAACGC': 63.47,
#  'CGTGGCGGTTCGGCGCCTTA': 62.41,
#  'CGCCGGAAGGCGGCGAACTA': 61.87,
#  'CAGAGACGTACGACCCCCGC': 58.96,
#  'CGACCGTCCCGACGACACTG': 59.51,
#  'GCGGGGGACGAGAAACGCCA': 61.76,
#  'CTTGCGTTCTCCGGCGCTGC': 61.58,
#  'GGTCGTCTCGTTTGCGGCCC': 60.65,
#  'CTTACTCCCCCCCCTCGTCG': 57.65,
#  'GCCGGGCGAGCGGTTAAGAG': 60.18,
#  'GCCCCCGTACCGCCAGAAAC': 60.04,
#  'CGCAGCACGCGACAACGGGA': 62.91,
#  'GAGTGCATCGCGGGGTTGGC': 61.0,
#  'AGCGGGTTCTACGCAGCGGG': 61.55,
#  'AGGCACGGTAAGCGCCGAGG': 61.55,
#  'CGGAACGACGCAGCGAACGG': 61.29,
#  'CACGCCCGCAACACCGACGA': 62.59,
#  'AAGGAGGGGGGGGGGAGAGA': 59.43,
#  'TCCTCGTGATCGCACCCGCG': 61.6,
#  'CTGTCACGCGGTCGTGCGCT': 62.64,
#  'GCATACGGCGCGGCACTCCA': 62.48,
#  'CGCGTTCGGGTTGGTCGTGG': 60.91,
#  'AGGGTTGGGGGGGGAGGATG': 59.22,
#  'AGGTGGGGGGGAGTTCGCTG': 60.18,
#  'CACACCGCAACCACTCCGCG': 61.18,
#  'CCCGACCGCACACGCGTTCA': 62.59,
#  'GCGGGGAGCCGGATAACGGA': 60.74,
#  'GGCTAGCGCGGGCGAATCTC': 60.31,
#  'CCACGAGCCCGGTAAACGGC': 60.38,
#  'CTTCGTCCCCCCCCCTCTCT': 58.66,
#  'CCCCCGGCGTACCTCGTTAC': 58.94,
#  'CGATGATGCGCGGCGAGCTC': 61.23,
#  'CCCAACCGAGCCCCCCCATT': 60.83,
#  'TGTCTCCGGGGCGGTTGAGC': 61.15,
#  'GGTCGAGGAACTTCGCGGGG': 59.5,
#  'CTTCGTCGGGCACGTCGACC': 60.11,
#  'TTTGGTTCGCGGGGGTGGCC': 62.28,
#  'CGTGCGTGCCCCTTCGTCCT': 61.75,
#  'GTTGCATCGTGGGGGGGGTG': 59.97,
#  'CGCCGTTGAACATCGCCCGC': 61.9,
#  'GGCGACCGATCGTGTCCGCT': 61.6,
#  'GCCGATATCCCCGCCGCTTC': 60.04,
#  'TGGGTCGCCTTTTGGCGGGG': 62.0,
#  'TGGGGGGTCGCATCTGTGCC': 61.17,
#  'CGTTCCCCCCCGGAGTTTCC': 59.06,
#  'GCCCGGACACGCGTACACCA': 61.75,
#  'GCACGCCACGTAGTCCGAGG': 59.84,
#  'CCAATCGACGCCCAACGCCC': 60.99,
#  'CTACTCCCCCCCCCTCCTTC': 56.54,
#  'CCGCCGTAAGGTAGCCGCTC': 59.64,
#  'TCGTGTCGTGCGCGGCACGT': 64.56,
#  'ACCGTTGCCACGCCGGAGGA': 63.17,
#  'CGACCGACCGTGACGAGGGA': 60.32,
#  'TCCAACCCCCCCCCCTCTAC': 58.56,
#  'GGGTCGCTTGTGCGAGTGCG': 61.24,
#  'CTCGACGTCTCCGGCCTACC': 58.41,
#  'CGTTCCCCCCCCCTGTACTC': 57.83,
#  'CACGTGGCGCCCTACCACTC': 59.77,
#  'GATGGACGGGTGGCGACTGG': 59.49,
#  'AGCCAGCCGCACGCGACCTA': 63.28,
#  'GGCAGGTGCGCGATTGGAGC': 61.33,
#  'GCCTGCGGTGTGCGTTACCG': 61.25,
#  'GTTTTTGCGGGGGCCTCGCG': 61.8,
#  'GGCCTTGCGCAGGTCGTGTG': 61.19,
#  'GAGGTAGCGGCGTACAGGCG': 59.64,
#  'ACGTCCGGGCGTCACCCTGT': 62.56,
#  'CGGCTAATACCGCACCGCCC': 60.25,
#  'GGTCGCGTAGCCGCCTACGT': 61.33,
#  'GGCGCGGGGGTTTTGCGTGT': 63.45,
#  'CCCGCCCGCGCAACATCAAC': 61.86,
#  'TGGCGACCGCTAAGTGGGGG': 60.88,
#  'GCACGCGCCGCACGAACCAA': 64.02,
#  'GTTCGGCTAGGCACGACCCG': 59.84,
#  'GTCCTTCGCTCACCGGCGCT': 61.81,
#  'GCGGCATGTCGCGGAACACC': 61.58,
#  'GCGGGCGACAAGATCGGCCT': 61.89,
#  'GGGGGGGTTTTCGCGTTCGC': 61.2,
#  'AACACTACCCCCCCGCCTCC': 59.89,
#  'CTACAACCCCCCCCCCTACC': 57.13,
#  'AGTCCGCCACGGAACGGGGA': 62.29,
#  'TACCTTGCCGTTCGCGCCCC': 62.1,
#  'GTCCCCGCGTAACCCCCGAA': 60.88,
#  'TGCCTTGGTCGCCGGATCCC': 61.23,
#  'CGGGACAATCGCAACCGGCC': 60.99,
#  'GACGGCAGCGCGCACTCATC': 61.37,
#  'GGGCTCGTTCGGTGTTGCGG': 60.92,
#  'GGACACGTAGCCTCGTCGGC': 59.57,
#  'TCCGATAGGGGGTGGACCGC': 59.76,
#  'CTCACCCCCCCCCCTACACA': 58.86,
#  'GCGAGGGGGCGTAACTGGCA': 61.5,
#  'CCGCCACCGCTCATCATCGC': 60.85,
#  'AGGGGCCGCGTTACGGTCGT': 62.94,
#  'CGTGTGCCGCGGTCGTATCC': 60.51,
#  'GTGGGGCGTCCGCGCTCAAA': 62.63,
#  'TTCCGCCGTTCGGTCCCACG': 61.75,
#  'GTCGTGGACGGCCGTCAGGT': 61.14,
#  'GGGGAGAGAGAGAGAGGGGG': 55.99,
#  'TCTTCGCGCCGGGTTCCCCT': 62.64,
#  'GTGTCGTCGCGTGGTGGGCT': 62.01,
#  'CTTGTCCGGTCCGCCGGTAC': 59.5,
#  'AGGGCGAACGAGTCACGCCC': 61.48,
#  'GAACGGGACCCGATCGGGCA': 60.94,
#  'CCGGGACCGTACCGTTCGCA': 61.2,
#  'CCGTTGTCCCCCCCCCTTTC': 58.97,
#  'GTGTGGCGTCGGTGTGCCCT': 61.97,
#  'AGGGTGTATGGGCGCGGGAG': 60.67,
#  'CCAGCGGCACCGGTCCTTAC': 59.77,
#  'CACCACAAGAAGCCGCGCGC': 62.1,
#  'TCGTTGTCTCGGCACCGCCG': 62.06,
#  'TCCCGTACCGGACGGGAACG': 60.32,
#  'CCCGATAGACCGCAGTCGGC': 59.36,
#  'CGTCGGGTGCGTCGTTGGTG': 60.91,
#  'CGCGCGCTCGTAGTGTGAGG': 60.51,
#  'TCTCGGCGCGTCGGAAGACC': 61.26,
#  'GCGTCTTGGGGTGCGCTCGT': 62.35,
#  'GGTGTTCGGCCGGTCGACTG': 60.04,
#  'CGGGTCCGGAGTCGTCGTTG': 59.51,
#  'CCCTTCCCCCCCCCTTTCCT': 59.14,
#  'GGTTGGCAACGGGTGACGGG': 60.52,
#  'AAGAGCGCCAGACCGCCCAC': 61.77,
#  'AGGACCCCACGCGACGACCA': 62.28,
#  'TGGGGCGGACCGTAGGAGTG': 59.97,
#  'ACAGGGGCCCGTCGCGATTG': 61.83,
#  'GGGCCTAATTGCGGCTGCGG': 61.07,
#  'CGTGTTGCCCGATAGCGCGC': 61.69,
#  'CAGGGTATACGGCGCTCCGG': 59.09,
#  'AGAGACGCGACGCCCGGTCA': 62.64,
#  'CTCCCTCCCCCCCCATCACA': 58.93,
#  'GGGGGGATGGGGGGTTATGG': 57.84,
#  'CTCGGTTCGTCCTCTGCGCG': 60.18,
#  'GGAGCGTGCATGACGGCCGA': 62.15,
#  'TCCCCCCTCCCTTCCCCCTT': 60.03,
#  'CCTGTTCCCCCCCCTCTTCC': 57.72,
#  'CAGGTCGCGGGGGTGAGCAT': 61.23,
#  'AAACCGACGCCGCACCCCAC': 62.57,
#  'AGCCCAGGGGCGCTATGGAC': 60.68,
#  'GCTCCTCCGTACGATCCGGG': 58.46,
#  'GGATCGGACGATCCGGCTGG': 59.08,
#  'CATGGACGGCACCGAGACCG': 59.84,
#  'AGGCCCGCGCCCTTACTCCT': 62.1,
#  'CAAGACCGTCGGCCTTCGGC': 60.38,
#  'GGGAAGGGGGGGGGAAAGAG': 57.7,
#  'GTGGGGGGAGGGGGAGAAAG': 57.72,
#  'CGTACGTTCGCGGCATGCCC': 61.37,
#  'GTGGCCGAGCGTCCATTCCG': 60.45,
#  'CCGATCCACGGGACCTCGCA': 60.66,
#  'ACCCGAGTCGCCTCGCCACT': 62.34,
#  'GGGCAGACCGCGACGAGCAA': 62.08,
#  'CCCCGAGCACGCCTTGTCAC': 60.32,
#  'GCGGCCCTACGTCCCGGAAT': 61.01,
#  'GGCGCGTGAGCGTGGCGATA': 62.52,
#  'AACCCCTCCCCCCACCCCAA': 61.23,
#  'GTTCGTCGACGCGGGGTGTG': 60.65,
#  'CGAGAAGGCCGTCGCGAACG': 60.77,
#  'AACAACCCCCCCCCCAACCC': 60.62,
#  'CGCCTAGACGTAGCGCTCGG': 59.45,
#  'ACGGTGGTCCGTGCGGTTGG': 61.96,
#  'ACCAGCACGGACGACCACGC': 62.01,
#  'GACCAGACGGCACGCCGAGA': 61.2,
#  'GTGCTTTGGACGCGTGCGGC': 62.36,
#  'GTTGTCGGGCGCTTGCTGCG': 62.1,
#  'CTCCTCCCCCCCCCATTCTC': 57.2,
#  'CCTTACGGCGTTACCCGCGC': 60.78,
#  'CTTGCGTAGGGCGACGACCG': 60.18,
#  'CGACACCCGCACGCCGAAAG': 61.24,
#  'CACACGGCACGCAACCCTGC': 61.72}

# %%
generator = PrimersGenerator(
    length=20,
    gc_percentage=0.3,
    number_of_primers=1000
)
primers = generator.generate_primers()

print(f"{len(primers)} primers generated")

filter_primers_by_blast(primers, blast_db_path=HG_38_BLAST_DB_PATH)
# Out:
# 1000 primers generated
# {'TCAAACTTTTTTTATCCGCT': 45.82,
#  'CACAAGAAAAAAAACGCAAA': 46.72,
#  'CTTGTCTTTTTTTTGTTGGT': 45.16,
#  'TCTTTCTTTTTTTTTGCTGC': 46.0,
#  'AAGAAAAAAAAAAACACGGC': 46.63,
#  'TTGATTTTTTTTTTCGCGCT': 48.23,
#  'GGTTTTTGTTTTTTTCTGCT': 45.84,
#  'AAGCAGAAAAAAAAACACTG': 45.61,
#  'CAAAGCAAAAACAAAAAACC': 45.54,
#  'AGAGACAAAAAAAACCAAAC': 44.87,
#  'AAAATAAAAAAAAAGGGGGG': 44.24,
#  'GGAAAAAAAAGAAAAAGAGC': 44.03,
#  'GGGTAGAAAAAGAAAAAAAG': 42.66,
#  'CTCTTTTTTTTGCTTTTTGC': 45.37,
#  'TACACCGAAACGTAAATAAT': 44.55,
#  'AAAAAAACCACAAAAAACCC': 45.92,
#  'TTAATATAACGCTAACGTGA': 44.13,
#  'ATTTGCTTTTTTTTCCTTCC': 45.19,
#  'CGAAAAAAGGAAAAATCCAA': 45.04}
